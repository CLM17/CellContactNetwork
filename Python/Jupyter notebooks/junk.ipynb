# %%
import os
from skimage import io

target_folder = 'Data\\WKS024\\2020-10-05'
row = 'B'
col = '02'
well_cols = [2,3,4,5,6,7]

well_folder = os.path.join(target_folder, row+col)
raw_folder = os.path.join(well_folder, 'raw')
tile_folder = os.path.join(well_folder, 'tiles')

# %%
file_list = os.listdir( well_folder )
# get first part of file name (is the same for all files in folder)
splitted_file = file_list[1].split('_')
img_info = splitted_file[0] + '_' + splitted_file[1] + '_'

# %%
fname_MEMBR = img_info + row + col + 'f' + '00' + 'd0.tif'
img_MEMBR = io.imread( os.path.join(well_folder, fname_MEMBR) )[:,:,0]
io.imshow(img_MEMBR)

# %%
img_MEMBR.shape
# Out:
# (1104, 1104, 3)
